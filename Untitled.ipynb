# %%
# !pip install requests pandas
# Out:
# Requirement already satisfied: requests in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.34.2)
# Requirement already satisfied: pandas in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (26.1.1)Note: you may need to restart the kernel to use updated packages.
#
# Collecting pip
#   Downloading pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 2.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.4 MB/s  0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 26.1.1
#     Uninstalling pip-26.1.1:
#       Successfully uninstalled pip-26.1.1
# Successfully installed pip-26.1.2

# %%
import requests

def get_weather(latitude, longitude, place_name=""):
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": latitude, "longitude": longitude,
        "daily": "temperature_2m_max,temperature_2m_min,precipitation_sum,precipitation_probability_max",
        "timezone": "Asia/Kolkata", "forecast_days": 7,
    }
    r = requests.get(url, params=params, timeout=20)
    r.raise_for_status()
    daily = r.json()["daily"]
    days = [{
        "date": daily["time"][i],
        "temp_max_c": daily["temperature_2m_max"][i],
        "temp_min_c": daily["temperature_2m_min"][i],
        "rain_mm": daily["precipitation_sum"][i],
        "rain_chance_pct": daily["precipitation_probability_max"][i],
    } for i in range(len(daily["time"]))]
    rain3 = round(sum(d["rain_mm"] for d in days[:3]), 1)
    return {
        "place": place_name, "forecast": days, "rain_next_3_days_mm": rain3,
        "summary": (f"Next 3 days rainfall: {rain3} mm. "
                    f"Tomorrow: {days[1]['temp_min_c']}-{days[1]['temp_max_c']}°C, "
                    f"{days[1]['rain_chance_pct']}% chance of rain."),
    }

# test it
print(get_weather(21.2514, 81.6296, "Raipur")["summary"])
# Out:
# Next 3 days rainfall: 23.7 mm. Tomorrow: 26.1-36.9°C, 76% chance of rain.

# %%
import pandas as pd
from mandi_data import _normalise, get_mandi_price

store = _normalise(pd.read_csv("mandi.csv"))
print("Loaded", len(store), "rows,", store["state"].nunique(), "states")
# Out:
# Loaded 5000 rows, 21 states

# %%
print(get_mandi_price("Paddy", state="Chhattisgarh", district="Raipur", df=store)["summary"])
print(get_mandi_price("Onion", state="Chhattisgarh", df=store)["summary"])
print(get_mandi_price("Tomato", state="Chhattisgarh", df=store)["summary"])
# Out:
# Paddy (Raipur district): 1 records. Modal Rs 1710-1710/quintal. Latest: Neora APMC on 21/06/2026 at Rs 1710.
# No Onion in Chhattisgarh yet; showing nearby-state prices as a proxy. Onion (nearby states): 15 records. Modal Rs 20-2000/quintal. Latest: Pune APMC on 21/06/2026 at Rs 20.
# No Tomato in Chhattisgarh yet; showing nearby-state prices as a proxy. Tomato (nearby states): 15 records. Modal Rs 1250-4000/quintal. Latest: Pune(Pimpri) APMC on 21/06/2026 at Rs 1600.

# %%
# !pip install google-genai pandas requests
# Out:
# Collecting google-genai
#   Downloading google_genai-2.9.0-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: pandas in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.2.2)
# Requirement already satisfied: requests in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.34.2)
# Collecting anyio<5.0.0,>=4.8.0 (from google-genai)
#   Downloading anyio-4.14.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting google-auth<3.0.0,>=2.48.1 (from google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading google_auth-2.55.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting httpx<1.0.0,>=0.28.1 (from google-genai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic<3.0.0,>=2.12.5 (from google-genai)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<17.0,>=13.0.0 (from google-genai)
#   Downloading websockets-16.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (4.15.0)
# Collecting distro<2,>=1.7.0 (from google-genai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: sniffio in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (2024.2.2)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading cryptography-49.0.0-cp311-abi3-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: httpcore==1.* in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.12.5->google-genai)
#   Using cached pydantic_core-2.46.4-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.12.5->google-genai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2024.1)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: pycparser in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.22)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Using cached pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading google_genai-2.9.0-py3-none-any.whl (950 kB)
#    ---------------------------------------- 0.0/950.8 kB ? eta -:--:--
#    --------------------------------- ------ 786.4/950.8 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 950.8/950.8 kB 1.8 MB/s  0:00:00
# Downloading anyio-4.14.0-py3-none-any.whl (123 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading google_auth-2.55.0-py3-none-any.whl (252 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Using cached pydantic_core-2.46.4-cp312-cp312-win_amd64.whl (2.1 MB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading websockets-16.0-cp312-cp312-win_amd64.whl (178 kB)
# Downloading cryptography-49.0.0-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 4.2 MB/s eta 0:00:01
#    ------------------- -------------------- 1.8/3.8 MB 3.9 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.8 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 3.1/3.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 3.5 MB/s  0:00:01
# Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: websockets, typing-inspection, tenacity, pydantic-core, pyasn1, distro, cffi, anyio, pydantic, pyasn1-modules, httpx, cryptography, google-auth, google-genai
#
#    ----------------------------------------  0/14 [websockets]
#    ----------------------------------------  0/14 [websockets]
#    ----------------------------------------  0/14 [websockets]
#    ----------------------------------------  0/14 [websockets]
#    ----------------------------------------  0/14 [websockets]
#    ----------------------------------------  0/14 [websockets]
#    ----- ----------------------------------  2/14 [tenacity]
#   Attempting uninstall: pydantic-core
#    ----- ----------------------------------  2/14 [tenacity]
#     Found existing installation: pydantic_core 2.18.4
#    ----- ----------------------------------  2/14 [tenacity]
#     Uninstalling pydantic_core-2.18.4:
#    ----- ----------------------------------  2/14 [tenacity]
#    -------- -------------------------------  3/14 [pydantic-core]
#       Successfully uninstalled pydantic_core-2.18.4
#    -------- -------------------------------  3/14 [pydantic-core]
#    ----------- ----------------------------  4/14 [pyasn1]
#    ----------- ----------------------------  4/14 [pyasn1]
#    ----------- ----------------------------  4/14 [pyasn1]
#    ----------- ----------------------------  4/14 [pyasn1]
#   Attempting uninstall: cffi
#    ----------- ----------------------------  4/14 [pyasn1]
#     Found existing installation: cffi 1.16.0
#    ----------- ----------------------------  4/14 [pyasn1]
#     Uninstalling cffi-1.16.0:
#    ----------- ----------------------------  4/14 [pyasn1]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#       Successfully uninstalled cffi-1.16.0
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#    ----------------- ----------------------  6/14 [cffi]
#   Attempting uninstall: anyio
#    ----------------- ----------------------  6/14 [cffi]
#     Found existing installation: anyio 4.3.0
#    ----------------- ----------------------  6/14 [cffi]
#    -------------------- -------------------  7/14 [anyio]
#     Uninstalling anyio-4.3.0:
#    -------------------- -------------------  7/14 [anyio]
#       Successfully uninstalled anyio-4.3.0
#    -------------------- -------------------  7/14 [anyio]
#    -------------------- -------------------  7/14 [anyio]
#    -------------------- -------------------  7/14 [anyio]
#    -------------------- -------------------  7/14 [anyio]
#    -------------------- -------------------  7/14 [anyio]
#    -------------------- -------------------  7/14 [anyio]
#    -------------------- -------------------  7/14 [anyio]
#   Attempting uninstall: pydantic
#    -------------------- -------------------  7/14 [anyio]
#     Found existing installation: pydantic 2.7.4
#    -------------------- -------------------  7/14 [anyio]
#     Uninstalling pydantic-2.7.4:
#    -------------------- -------------------  7/14 [anyio]
#       Successfully uninstalled pydantic-2.7.4
#    -------------------- -------------------  7/14 [anyio]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ---------------------- -----------------  8/14 [pydantic]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ------------------------- --------------  9/14 [pyasn1-modules]
#   Attempting uninstall: httpx
#    ------------------------- --------------  9/14 [pyasn1-modules]
#     Found existing installation: httpx 0.27.0
#    ------------------------- --------------  9/14 [pyasn1-modules]
#     Uninstalling httpx-0.27.0:
#    ------------------------- --------------  9/14 [pyasn1-modules]
#       Successfully uninstalled httpx-0.27.0
#    ------------------------- --------------  9/14 [pyasn1-modules]
#    ---------------------------- ----------- 10/14 [httpx]
#    ---------------------------- ----------- 10/14 [httpx]
#    ---------------------------- ----------- 10/14 [httpx]
#    ---------------------------- ----------- 10/14 [httpx]
#    ------------------------------- -------- 11/14 [cryptography]
#    ------------------------------- -------- 11/14 [cryptography]
#    ------------------------------- -------- 11/14 [cryptography]
#    ------------------------------- -------- 11/14 [cryptography]
#    ------------------------------- -------- 11/14 [cryptography]
#    ------------------------------- -------- 11/14 [cryptography]
#    ------------------------------- -------- 11/14 [cryptography]
#    ------------------------------- -------- 11/14 [cryptography]
#    ---------------------------------- ----- 12/14 [google-auth]
#    ---------------------------------- ----- 12/14 [google-auth]
#    ---------------------------------- ----- 12/14 [google-auth]
#    ---------------------------------- ----- 12/14 [google-auth]
#    ---------------------------------- ----- 12/14 [google-auth]
#    ---------------------------------- ----- 12/14 [google-auth]
#    ---------------------------------- ----- 12/14 [google-auth]
#    ---------------------------------- ----- 12/14 [google-auth]
#    ---------------------------------- ----- 12/14 [google-auth]
#    ---------------------------------- ----- 12/14 [google-auth]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ------------------------------------- -- 13/14 [google-genai]
#    ---------------------------------------- 14/14 [google-genai]
#
# Successfully installed anyio-4.14.0 cffi-2.0.0 cryptography-49.0.0 distro-1.9.0 google-auth-2.55.0 google-genai-2.9.0 httpx-0.28.1 pyasn1-0.6.3 pyasn1-modules-0.4.2 pydantic-2.13.4 pydantic-core-2.46.4 tenacity-9.1.4 typing-inspection-0.4.2 websockets-16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.4.2 which is incompatible.
# pandas-profiling 3.2.0 requires markupsafe~=2.1.1, but you have markupsafe 3.0.3 which is incompatible.

# %%
"""
KisanMitra — Phase 2: The Agent Core (minimal)
==============================================
A farmer asks a free-text question (Hindi or English). Gemini decides which
tools to call, calls get_weather + get_mandi_price automatically, then reasons
across both to give ONE clear recommendation in the farmer's language.

This is the heart of the project. It uses the google-genai SDK's AUTOMATIC
function calling: you just hand Gemini your Python functions as tools, and it
does the call-the-tool / read-the-result / decide loop for you.

Run order in a notebook:
  1. pip install google-genai pandas requests
  2. Make sure mandi_data.py is importable and you have a snapshot loaded.
  3. Paste your Gemini API key below.
  4. ask("मेरे पास धान है, अभी बेचूं या रुकूं?  जिला रायपुर")
"""

from google import genai
from google.genai import types

# Your data tools from Phase 1
from mandi_data import get_mandi_price as _raw_mandi_price, load_store
import requests

GEMINI_API_KEY = "paste-your-real-key-here"   # <-- from aistudio.google.com
MODEL = "gemini-2.5-flash"   # fast, free-tier friendly, great for this

# Load the mandi store once so the tool is fast on every call
_STORE = load_store()

# A small map so the agent can turn a district name into coordinates for weather.
# Add more as you like; these cover Chhattisgarh's main areas.
DISTRICT_COORDS = {
    "raipur": (21.2514, 81.6296),
    "durg": (21.1904, 81.2849),
    "bilaspur": (22.0797, 82.1409),
    "raigarh": (21.8974, 83.3950),
    "jagdalpur": (19.0748, 82.0119),
    "ambikapur": (23.1206, 83.1959),
}

# ---------------------------------------------------------------------------
# TOOLS — these are what Gemini will call. The docstrings MATTER: Gemini reads
# them to decide when and how to call each tool. Keep them clear.
# ---------------------------------------------------------------------------

def get_weather_for_district(district: str) -> str:
    """Get the 7-day weather forecast for a district in Chhattisgarh, India.
    Use this to understand rainfall and temperature before advising a farmer
    about harvesting, spraying, or irrigation.

    Args:
        district: District name, e.g. 'Raipur', 'Durg', 'Bilaspur'.
    """
    key = district.strip().lower()
    lat, lon = DISTRICT_COORDS.get(key, DISTRICT_COORDS["raipur"])
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": lat, "longitude": lon,
        "daily": "temperature_2m_max,temperature_2m_min,precipitation_sum,precipitation_probability_max",
        "timezone": "Asia/Kolkata", "forecast_days": 7,
    }
    try:
        r = requests.get(url, params=params, timeout=20)
        r.raise_for_status()
        d = r.json()["daily"]
    except Exception as e:
        return f"Weather unavailable ({e})."
    lines = []
    for i in range(min(5, len(d["time"]))):
        lines.append(
            f"{d['time'][i]}: {d['temperature_2m_min'][i]}-{d['temperature_2m_max'][i]}°C, "
            f"rain {d['precipitation_sum'][i]}mm ({d['precipitation_probability_max'][i]}% chance)")
    rain3 = round(sum(d["precipitation_sum"][:3]), 1)
    return (f"Weather for {district} (next 5 days):\n" + "\n".join(lines) +
            f"\nTotal rain next 3 days: {rain3} mm.")


def get_crop_price(commodity: str, district: str = "Raipur") -> str:
    """Get recent mandi (market) prices for a crop, in Rupees per quintal.
    Use this to advise a farmer whether prices are good for selling.
    Returns min/max/modal prices and which market and date they are from.

    Args:
        commodity: Crop name, e.g. 'Paddy', 'Onion', 'Tomato', 'Wheat'.
        district: Farmer's district in Chhattisgarh, e.g. 'Raipur'.
    """
    res = _raw_mandi_price(commodity, state="Chhattisgarh",
                           district=district, df=_STORE, limit=8)
    # Drop obviously-bad rows (e.g. junk Rs 20 prices) for sanity
    good = [r for r in res["records"]
            if r.get("modal_price") and r["modal_price"] >= 100]
    if not good:
        return res["summary"]
    lines = [f"{r['market']} ({r['arrival_date']}): "
             f"modal Rs {int(r['modal_price'])}/qtl "
             f"[min {int(r['min_price'])}, max {int(r['max_price'])}]"
             for r in good[:6]]
    return f"{res['summary']}\nRecent records:\n" + "\n".join(lines)


# ---------------------------------------------------------------------------
# THE AGENT — system prompt + one call with both tools attached
# ---------------------------------------------------------------------------

SYSTEM_PROMPT = """You are KisanMitra, a friendly farming advisor for small
farmers in Chhattisgarh, India.

Your job: given a farmer's question, give ONE clear, practical recommendation.

Rules:
- ALWAYS reason across BOTH weather AND market price before deciding. Call the
  weather tool and the price tool, then combine what they tell you.
- If the farmer asks whether to sell/harvest/wait, your answer must weigh:
  upcoming rain (can they harvest/dry the crop?) AND current price trend
  (is it worth selling now?).
- Reply in the SAME language the farmer used (Hindi or English). If they wrote
  in Hindi, answer in simple Hindi.
- Keep it short and actionable: 3-5 sentences. Start with the recommendation,
  then the 'because'. Mention the actual numbers you used (price, rain) so the
  farmer trusts the advice.
- If data is missing or from a nearby market, say so honestly.
- Never invent prices or weather. Only use what the tools return.
"""

_client = genai.Client(api_key=GEMINI_API_KEY)


def ask(question: str) -> str:
    """Ask KisanMitra a free-text farming question (Hindi or English)."""
    response = _client.models.generate_content(
        model=MODEL,
        contents=question,
        config=types.GenerateContentConfig(
            system_instruction=SYSTEM_PROMPT,
            tools=[get_weather_for_district, get_crop_price],
            temperature=0.3,
        ),
    )
    return response.text


if __name__ == "__main__":
    # These will only run with a real key + internet for Gemini & weather.
    print(ask("I grow paddy in Raipur. Should I sell now or wait? "))
    print("\n" + "=" * 60 + "\n")
    print(ask("मेरे पास रायपुर में प्याज है, अभी बेचूं या रुकूं?"))

# %%
print(ask("I grow paddy in Raipur. Should I sell now or wait?"))
# Out:
# अभी बेच देना अच्छा रहेगा.
#
# अगले 3 दिनों में रायपुर में कुल 23.7 मिमी बारिश होने की संभावना है, जिससे धान सुखाने में दिक्कत हो सकती है. धान का भाव अभी 1710 रुपये प्रति क्विंटल चल रहा है (नेओरा मंडी, 21/06/2026). बारिश से पहले बेचकर आप अपनी फसल को खराब होने से बचा सकते हैं और अच्छा दाम भी पा सकते हैं.

# %%
pip install streamlit google-genai pandas requests
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting streamlit
#   Downloading streamlit-1.58.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: google-genai in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.9.0)
# Requirement already satisfied: pandas in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.2.2)
# Requirement already satisfied: requests in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.34.2)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.2.1-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<8,>=5.5 (from streamlit)
#   Downloading cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from streamlit) (8.4.1)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.50-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging>=20 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from streamlit) (24.0)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from streamlit) (10.3.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: protobuf<8,>=3.20 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from streamlit) (9.1.4)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from streamlit) (4.15.0)
# Collecting starlette>=0.40.0 (from streamlit)
#   Downloading starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting uvicorn>=0.30.0 (from streamlit)
#   Using cached uvicorn-0.49.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting httptools>=0.6.3 (from streamlit)
#   Downloading httptools-0.8.0-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: anyio>=4.0.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from streamlit) (4.14.0)
# Collecting python-multipart>=0.0.10 (from streamlit)
#   Downloading python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: websockets>=12.0.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from streamlit) (16.0)
# Collecting itsdangerous>=2.1.2 (from streamlit)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: jinja2 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.21.1)
# Requirement already satisfied: narwhals>=2.4.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.15.0)
# Requirement already satisfied: colorama in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.55.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (49.0.0)
# Requirement already satisfied: httpcore==1.* in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)
# Requirement already satisfied: six>=1.5 in C:\Users\ayaan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading streamlit-1.58.0-py3-none-any.whl (9.2 MB)
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.2 MB 3.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.2 MB 2.7 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.2 MB 2.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.6/9.2 MB 3.0 MB/s eta 0:00:03
#    -------------- ------------------------- 3.4/9.2 MB 3.1 MB/s eta 0:00:02
#    ------------------ --------------------- 4.2/9.2 MB 3.2 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.2 MB 3.4 MB/s eta 0:00:02
#    ------------------------- -------------- 5.8/9.2 MB 3.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.6/9.2 MB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.2 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.1/9.2 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 3.5 MB/s  0:00:02
# Downloading altair-6.2.1-py3-none-any.whl (797 kB)
#    ---------------------------------------- 0.0/797.5 kB ? eta -:--:--
#    ---------------------------------------- 797.5/797.5 kB 3.8 MB/s  0:00:00
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-7.1.4-py3-none-any.whl (16 kB)
# Downloading gitpython-3.1.50-py3-none-any.whl (212 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.3 MB 3.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.3 MB 4.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/11.3 MB 3.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.3 MB 3.9 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.3 MB 3.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.3 MB 3.9 MB/s eta 0:00:02
#    -------------------- ------------------- 5.8/11.3 MB 3.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.3 MB 3.9 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.3 MB 3.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.3 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.3 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 3.8 MB/s  0:00:02
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading httptools-0.8.0-cp312-cp312-win_amd64.whl (90 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Downloading starlette-1.3.1-py3-none-any.whl (73 kB)
# Using cached uvicorn-0.49.0-py3-none-any.whl (71 kB)
# Installing collected packages: watchdog, toml, smmap, python-multipart, itsdangerous, httptools, cachetools, blinker, uvicorn, starlette, pydeck, gitdb, gitpython, altair, streamlit
#
#    ----------------------------------------  0/15 [watchdog]
#    ----------------------------------------  0/15 [watchdog]
#    ----------------------------------------  0/15 [watchdog]
#    ----------------------------------------  0/15 [watchdog]
#    -- -------------------------------------  1/15 [toml]
#    ----- ----------------------------------  2/15 [smmap]
#    -------- -------------------------------  3/15 [python-multipart]
#    ---------- -----------------------------  4/15 [itsdangerous]
#    ------------- --------------------------  5/15 [httptools]
#    ------------------ ---------------------  7/15 [blinker]
#    --------------------- ------------------  8/15 [uvicorn]
#    --------------------- ------------------  8/15 [uvicorn]
#    --------------------- ------------------  8/15 [uvicorn]
#    --------------------- ------------------  8/15 [uvicorn]
#    ------------------------ ---------------  9/15 [starlette]
#    ------------------------ ---------------  9/15 [starlette]
#    ------------------------ ---------------  9/15 [starlette]
#    ------------------------ ---------------  9/15 [starlette]
#    -------------------------- ------------- 10/15 [pydeck]
#    -------------------------- ------------- 10/15 [pydeck]
#    -------------------------- ------------- 10/15 [pydeck]
#    -------------------------- ------------- 10/15 [pydeck]
#    -------------------------- ------------- 10/15 [pydeck]
#    ----------------------------- ---------- 11/15 [gitdb]
#    ----------------------------- ---------- 11/15 [gitdb]
#    -------------------------------- ------- 12/15 [gitpython]
#    -------------------------------- ------- 12/15 [gitpython]
#    -------------------------------- ------- 12/15 [gitpython]
#    -------------------------------- ------- 12/15 [gitpython]
#    -------------------------------- ------- 12/15 [gitpython]
#    ---------------------------------- ----- 13/15 [altair]
#    ---------------------------------- ----- 13/15 [altair]
#    ---------------------------------- ----- 13/15 [altair]
#    ---------------------------------- ----- 13/15 [altair]
#    ---------------------------------- ----- 13/15 [altair]
#    ---------------------------------- ----- 13/15 [altair]
#    ---------------------------------- ----- 13/15 [altair]
#    ---------------------------------- ----- 13/15 [altair]
#    ---------------------------------- ----- 13/15 [altair]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ------------------------------------- -- 14/15 [streamlit]
#    ---------------------------------------- 15/15 [streamlit]
#
# Successfully installed altair-6.2.1 blinker-1.9.0 cachetools-7.1.4 gitdb-4.0.12 gitpython-3.1.50 httptools-0.8.0 itsdangerous-2.2.0 pydeck-0.9.2 python-multipart-0.0.32 smmap-5.0.3 starlette-1.3.1 streamlit-1.58.0 toml-0.10.2 uvicorn-0.49.0 watchdog-6.0.0

# %%
import os
os.makedirs(".streamlit", exist_ok=True)
with open(".streamlit/secrets.toml", "w") as f:
    f.write('GEMINI_API_KEY = "paste-your-real-key-here"')
print("Done — secrets file created.")
# Out:
# Done — secrets file created.
